# %%
import pandas as pd
import numpy as np
import sqlite3
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("netflix data C W project.csv")
data
# Out:
#                                            title   type  \
# 0                                   Forrest Gump  movie
# 1                              The Fifth Element  movie
# 2                              Kill Bill: Vol. 1  movie
# 3                                        Jarhead  movie
# 4                                     Unforgiven  movie
# ...                                          ...    ...
# 20143                                        NaN     tv
# 20144                                        NaN     tv
# 20145                                        NaN     tv
# 20146                                        NaN     tv
# 20147  Blippi's Ultimate Bounce House Challenges     tv
#
#                               genres  releaseYear      imdbId  \
# 0                     Drama, Romance       1994.0   tt0109830
# 1          Action, Adventure, Sci-Fi       1997.0   tt0119116
# 2            Action, Crime, Thriller       2003.0   tt0266697
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#                                            title   type  \
# 0                                   Forrest Gump  movie
# 1                              The Fifth Element  movie
# 2                              Kill Bill: Vol. 1  movie
# 3                                        Jarhead  movie
# 4                                     Unforgiven  movie
# ...                                          ...    ...
# 20143                                        NaN     tv
# 20144                                        NaN     tv
# 20145                                        NaN     tv
# 20146                                        NaN     tv
# 20147  Blippi's Ultimate Bounce House Challenges     tv
#
#                               genres  releaseYear      imdbId  \
# 0                     Drama, Romance       1994.0   tt0109830
# 1          Action, Adventure, Sci-Fi       1997.0   tt0119116
# 2            Action, Crime, Thriller       2003.0   tt0266697
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20148 entries, 0 to 20147
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               19632 non-null  object
#  1   type                20148 non-null  object
#  2   genres              19886 non-null  object
#  3   releaseYear         20133 non-null  float64
#  4   imdbId              18868 non-null  object
#  5   imdbAverageRating   18727 non-null  float64
#  6   imdbNumVotes        18727 non-null  float64
#  7   availableCountries  20148 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 1.2+ MB

# %%
# Drop rows with no title or release year
df = df.dropna(subset=['title', 'releaseYear'])

# %%
# Fill missing rating with a placeholder
df['rating'] = df['imdbAverageRating'].fillna('Not Rated')
df.drop("imdbAverageRating" , axis = 1 )
# Out:
#                                            title   type  \
# 0                                   Forrest Gump  movie
# 1                              The Fifth Element  movie
# 2                              Kill Bill: Vol. 1  movie
# 3                                        Jarhead  movie
# 4                                     Unforgiven  movie
# ...                                          ...    ...
# 20131              The Manhattan Alien Abduction     tv
# 20133               Children of the Church Steps     tv
# 20136                            Don't Come Home     tv
# 20140       The Evolution of Black British Music     tv
# 20147  Blippi's Ultimate Bounce House Challenges     tv
#
#                           genres  releaseYear      imdbId  imdbNumVotes  \
# 0                 Drama, Romance       1994.0   tt0109830     2316353.0
# 1      Action, Adventure, Sci-Fi       1997.0   tt0119116      517121.0
# 2        Action, Crime, Thriller       2003.0   tt0266697     1221791.0
# ...

# %% [markdown]
# # Handling Missing IMDb Ratings
#
# Many entries in the dataset have missing IMDb ratings. To ensure consistency and avoid issues during analysis or visualization, these missing values were replaced with the placeholder `'Not Rated'`. This makes it easier to identify unrated titles during analysis without excluding them.
#
# After replacement, the original `imdbAverageRating` column was dropped to keep the dataset clean and avoid redundancy, since all necessary info is now stored in the new `rating` column.
#
# This step is crucial in:
# - Preserving all records, even those with incomplete data
# - Making future groupings and filtering based on ratings easier
# - Ensuring that rating-related visualizations (like bar charts) include the `"Not Rated"` category

# %%
df = df.dropna(subset=['imdbNumVotes'])
df
# Out:
#                                       title   type                     genres  \
# 0                              Forrest Gump  movie             Drama, Romance
# 1                         The Fifth Element  movie  Action, Adventure, Sci-Fi
# 2                         Kill Bill: Vol. 1  movie    Action, Crime, Thriller
# 3                                   Jarhead  movie      Biography, Drama, War
# 4                                Unforgiven  movie             Drama, Western
# ...                                     ...    ...                        ...
# 20130           This Is the Zodiac Speaking     tv         Crime, Documentary
# 20131         The Manhattan Alien Abduction     tv                Documentary
# 20133          Children of the Church Steps     tv   Drama, History, Thriller
# 20136                       Don't Come Home     tv     Drama, Horror, Mystery
# 20140  The Evolution of Black British Music     tv         Documentary, Music
#
# ...

# %%
# Normalize genres (listed_in) to a list format
df['genres'] = df['genres'].apply(lambda x: [genre.strip('') for genre in x.split(',')] if isinstance(x, str) else x)
df = df.dropna(subset=['genres'])
df.head(10)
# Out:
#                                    title   type  \
# 0                           Forrest Gump  movie
# 1                      The Fifth Element  movie
# 2                      Kill Bill: Vol. 1  movie
# 3                                Jarhead  movie
# 4                             Unforgiven  movie
# 5  Eternal Sunshine of the Spotless Mind  movie
# 6                          Amores Perros  movie
# 7                  A History of Violence  movie
# 8                  2001: A Space Odyssey  movie
# 9                            Talk to Her  movie
#
#                           genres  releaseYear     imdbId  imdbAverageRating  \
# 0              [Drama,  Romance]       1994.0  tt0109830                8.8
# 1  [Action,  Adventure,  Sci-Fi]       1997.0  tt0119116                7.6
# 2    [Action,  Crime,  Thriller]       2003.0  tt0266697                8.2
# 3      [Biography,  Drama,  War]       2005.0  tt0418763                7.0
# ...

# %%
# Normalize country availability to a list
df['countries'] = df['availableCountries'].fillna('').apply(lambda x: [country.strip() for country in x.split(',') if country.strip()])
df.head(10)
# Out:
#                                    title   type  \
# 0                           Forrest Gump  movie
# 1                      The Fifth Element  movie
# 2                      Kill Bill: Vol. 1  movie
# 3                                Jarhead  movie
# 4                             Unforgiven  movie
# 5  Eternal Sunshine of the Spotless Mind  movie
# 6                          Amores Perros  movie
# 7                  A History of Violence  movie
# 8                  2001: A Space Odyssey  movie
# 9                            Talk to Her  movie
#
#                           genres  releaseYear     imdbId  imdbAverageRating  \
# 0              [Drama,  Romance]       1994.0  tt0109830                8.8
# 1  [Action,  Adventure,  Sci-Fi]       1997.0  tt0119116                7.6
# 2    [Action,  Crime,  Thriller]       2003.0  tt0266697                8.2
# 3      [Biography,  Drama,  War]       2005.0  tt0418763                7.0
# ...

# %% [markdown]
# #  Normalize Genre Information
#
# The `genres` column (previously `listed_in`) contains multiple genres in a single string, separated by commas. To enable easier filtering, analysis, and visualization, we normalize this column by:
# - Splitting the string into a list of individual genres
# - Stripping extra spaces from each genre
# - Dropping rows with missing genre data
#
# This results in a structured `genres` column where each entry is a list of clean genre names.

# %%
# Drop duplicates based on show_id
df = df.drop_duplicates(subset=['imdbId'])
df.head(10)
# Out:
#                                    title   type  \
# 0                           Forrest Gump  movie
# 1                      The Fifth Element  movie
# 2                      Kill Bill: Vol. 1  movie
# 3                                Jarhead  movie
# 4                             Unforgiven  movie
# 5  Eternal Sunshine of the Spotless Mind  movie
# 6                          Amores Perros  movie
# 7                  A History of Violence  movie
# 8                  2001: A Space Odyssey  movie
# 9                            Talk to Her  movie
#
#                           genres  releaseYear     imdbId  imdbAverageRating  \
# 0              [Drama,  Romance]       1994.0  tt0109830                8.8
# 1  [Action,  Adventure,  Sci-Fi]       1997.0  tt0119116                7.6
# 2    [Action,  Crime,  Thriller]       2003.0  tt0266697                8.2
# 3      [Biography,  Drama,  War]       2005.0  tt0418763                7.0
# ...

# %%
df.dtypes
# Out:
# title                  object
# type                   object
# genres                 object
# releaseYear           float64
# imdbId                 object
# imdbAverageRating     float64
# imdbNumVotes          float64
# availableCountries     object
# rating                 object
# countries              object
# dtype: object

# %%
# Clean column names to snake_case for SQL
df.columns = [col.strip().lower().replace(' ', '_') for col in df.columns]
df.head(10)
# Out:
#                                    title   type  \
# 0                           Forrest Gump  movie
# 1                      The Fifth Element  movie
# 2                      Kill Bill: Vol. 1  movie
# 3                                Jarhead  movie
# 4                             Unforgiven  movie
# 5  Eternal Sunshine of the Spotless Mind  movie
# 6                          Amores Perros  movie
# 7                  A History of Violence  movie
# 8                  2001: A Space Odyssey  movie
# 9                            Talk to Her  movie
#
#                           genres  releaseyear     imdbid  imdbaveragerating  \
# 0              [Drama,  Romance]       1994.0  tt0109830                8.8
# 1  [Action,  Adventure,  Sci-Fi]       1997.0  tt0119116                7.6
# 2    [Action,  Crime,  Thriller]       2003.0  tt0266697                8.2
# 3      [Biography,  Drama,  War]       2005.0  tt0418763                7.0
# ...

# %% [markdown]
# # Clean Column Names
#
# # Standardize column names to snake_case for consistency and easier acceaning:
#
# Improved Code Readability: Using snake_case aligns with Python naming conventions, making it easier to work with DataFrame columns programmatically.
#
# Avoid Future Errors: By removing spaces and converting to lowercase, we reduce the chances of runtime errors due to inconsistent naming (e.g., df['Column Name'] vs df['column_name']).
#
# Prepared for SQL-style Queries: While not using SQL directly here, having clean names supports pandasql or exporting the data to SQL databases later.
#
# Initial Data Exploration: Displaying the first 10 rows allows for:
#
# A quick glance at the data's structure.
#
# Early detection of data quality issues (e.g., missing values, outliers).
#
# Familiarization with column types and potential categorical/numerical splits.

# %%
# !pip install pymysql sqlalchemy

# %%
from sqlalchemy import create_engine

# Replace the values below with your actual MySQL credentials
username = 'root'         # your MySQL username
password = '998629' # your MySQL password
host = 'localhost'        # or 127.0.0.1
port = 3306               # default MySQL port
database = 'netflixproject'      # make sure this DB exists

# Create the SQLAlchemy engine
engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}")

# %% [markdown]
# # Connect to MySQL Database
#
#
# Database Connectivity Established: A connection has been successfully configured to the netflixproject MySQL database using SQLAlchemy.
#
# Secure Credential Handling (Recommendation): While credentials are hardcoded here for simplicity, it's recommended to use environment variables or a .env file in production environments to enhance security.
#
# Reusability & Flexibility: The engine object can now be used with pandas (pd.read_sql) to run SQL queries directly and fetch data into DataFrames for analysis.
#
# Cross-Platform Integration: SQLAlchemy provides a powerful bridge between SQL and Python, enabling the blending of SQL querying with pandas data manipulation and visualization.
#
# Next Step Guidance: Now that the connection is ready, you can:
#
# Inspect available tables.
#
# Load specific tables into DataFrames.
#
# Run SQL queries and perform data analysis directly from the notebook.

# %%
engine = create_engine("mysql+pymysql://root:998629@localhost:3306/netflixproject")

# %%
df.head()
# Out:
#                title   type                         genres  releaseyear  \
# 0       Forrest Gump  movie              [Drama,  Romance]       1994.0
# 1  The Fifth Element  movie  [Action,  Adventure,  Sci-Fi]       1997.0
# 2  Kill Bill: Vol. 1  movie    [Action,  Crime,  Thriller]       2003.0
# 3            Jarhead  movie      [Biography,  Drama,  War]       2005.0
# 4         Unforgiven  movie              [Drama,  Western]       1992.0
#
#       imdbid  imdbaveragerating  imdbnumvotes  \
# 0  tt0109830                8.8     2316353.0
# 1  tt0119116                7.6      517121.0
# 2  tt0266697                8.2     1221791.0
# 3  tt0418763                7.0      211547.0
# 4  tt0105695                8.2      443775.0
#
#                                   availablecountries rating  \
# 0                                                 MX    8.8
# 1                                         AT, CH, DE    7.6
# 2  AE, AL, AO, AT, AU, AZ, BG, BH, BY, CA, CI, CM...    8.2
# ...

# %%
list_columns = ['genres', 'availablecountries', 'countries']
for col in list_columns:
    df[col] = df[col].astype(str)

# %%
df.to_sql('netflix', con=engine, if_exists='replace', index=False)
# Out:
# 18723

# %%
df.tail(10)
# Out:
#                                       title type  \
# 20115                   My Dress-Up Darling   tv
# 20119                          Blood Legacy   tv
# 20120                 Chef's Table: Noodles   tv
# 20123     The Comeback: 2004 Boston Red Sox   tv
# 20128                 Making It in Marbella   tv
# 20130           This Is the Zodiac Speaking   tv
# 20131         The Manhattan Alien Abduction   tv
# 20133          Children of the Church Steps   tv
# 20136                       Don't Come Home   tv
# 20140  The Evolution of Black British Music   tv
#
#                                    genres  releaseyear      imdbid  \
# 20115              ['Comedy', ' Romance']       2024.0  tt33303711
# 20119              ['Drama', ' Thriller']       2024.0  tt33344252
# 20120                     ['Documentary']       2024.0  tt33323674
# 20123           ['Documentary', ' Sport']       2024.0  tt33356012
# 20128                      ['Reality-TV']       2024.0  tt31828643
# ...
